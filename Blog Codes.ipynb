# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_nse = pd.read_excel('NSE.xlsx')
data_nifty50 = pd.read_excel('NIFTY_50.xlsx')
data_bnifty = pd.read_excel('NIFTY_BANK.xlsx')

# %%
df = pd.concat([data_nse, data_nifty50, data_bnifty], axis=0)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.drop_duplicates(subset=['TIC'])
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                TIC  Latest Price  Score  PE Ratio  Dividend        SMA_20  \
# 0        KERNEX.NS    280.649994    100       NaN      1.00    325.447498
# 1        ROHLTD.NS    274.500000    100     13.33      2.00    284.735001
# 2       UCOBANK.NS     35.599998     99     37.53      2.00     22.550000
# 3      ADANIENT.NS   4043.750000     98    586.44      1.00   3973.047510
# 4       KTKBANK.NS    159.899994     99      5.67      4.00    149.995000
# ..             ...           ...    ...       ...       ...           ...
# 519   COALINDIA.NS    253.250000     93      5.97      3.00    243.805000
# 520   NESTLEIND.NS  20322.500000     86     90.50    120.00  19993.376563
# 521    HDFCLIFE.NS    542.650024     10     74.95      1.70    534.902502
# 522  IDFCFIRSTB.NS     57.549999     58     21.97      0.75     56.547500
# 523  BANDHANBNK.NS    226.350006     17      9.28      1.00    251.122503
#
#            SMA_50  52_Week_Low  52_Week_High  Annual Volatility  Sharpe Ratio  \
# 0      340.965997        79.65        389.90           0.520918          3.13
# 1      278.629001        80.00        317.70           0.539601          2.72
# 2       16.937000        10.55         36.55           0.432644          2.68
# 3     3701.830005      1528.80       4096.00           0.364070          2.61
# 4      122.286000        55.20        168.50           0.421600          2.60
# ..            ...          ...           ...                ...           ...
# 519    234.082000       139.15        263.40           0.351835          1.48
# 520  19326.864570     16000.00      21050.00           0.199398          0.20
# 521    544.281000       497.05        723.95           0.288025         -0.57
# 522     52.985000        28.95         59.45           0.392747          0.22
# 523    267.983999       220.05        349.55           0.414033         -0.46
#
#         MaxDD      CVaR       VaR
# 0   -0.301682  0.049846  0.049419
# 1   -0.232167  0.057922  0.045891
# 2   -0.231884  0.035195  0.022053
# 3   -0.177788  0.050961  0.033499
# 4   -0.183358  0.042452  0.027571
# ..        ...       ...       ...
# 519 -0.192605  0.046943  0.032675
# 520 -0.185800  0.027574  0.021461
# 521 -0.294423  0.041799  0.029483
# 522 -0.440499  0.048627  0.033630
# 523 -0.349876  0.068786  0.041728
#
# [524 rows x 14 columns]
