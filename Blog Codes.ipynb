# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_nse = pd.read_excel('NSE.xlsx')
data_nifty50 = pd.read_excel('NIFTY_50.xlsx')
data_bnifty = pd.read_excel('NIFTY_BANK.xlsx')

# %%
df = pd.concat([data_nse, data_nifty50, data_bnifty], axis=0)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.drop_duplicates(subset=['TIC'])
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                TIC  Latest Price  Score  PE Ratio  Dividend        SMA_20  \
# 0      GILLETTE.NS   5111.950195     40     56.62     36.00   5108.647510
# 1        SANOFI.NS   5892.450195     24     23.39    193.00   5637.330054
# 2        COLPAL.NS   1656.949951     67     42.37     18.00   1596.089996
# 3        PFIZER.NS   4403.200195     36     40.28      5.00   4494.837500
# 4     AKZOINDIA.NS   2251.149902     61     34.09     35.00   2309.515002
# ..             ...           ...    ...       ...       ...           ...
# 521   COALINDIA.NS    253.250000     93      5.97      3.00    243.805000
# 522   NESTLEIND.NS  20322.500000     86     90.50    120.00  19993.376563
# 523    HDFCLIFE.NS    542.650024     10     74.95      1.70    534.902502
# 524  IDFCFIRSTB.NS     57.549999     58     21.97      0.75     56.547500
# 525  BANDHANBNK.NS    226.350006     17      9.28      1.00    251.122503
#
#            SMA_50  52_Week_Low  52_Week_High  Annual Volatility  Sharpe Ratio  \
# 0     5120.303682      4748.00       5624.95           0.167355         -0.23
# 1     5681.879033      5454.00       7940.00           0.178978         -0.68
# 2     1585.552266      1375.60       1695.95           0.198662          0.66
# 3     4422.269980      4060.00       5235.55           0.202368         -0.29
# 4     2222.492004      1687.60       2400.00           0.205200          0.47
# ..            ...          ...           ...                ...           ...
# 521    234.082000       139.15        263.40           0.351835          1.48
# 522  19326.864570     16000.00      21050.00           0.199398          0.20
# 523    544.281000       497.05        723.95           0.288025         -0.57
# 524     52.985000        28.95         59.45           0.392747          0.22
# 525    267.983999       220.05        349.55           0.414033         -0.46
#
#         MaxDD      CVaR       VaR
# 0   -0.115818  0.022034  0.016513
# 1   -0.255909  0.024289  0.019066
# 2   -0.094461  0.027213  0.020759
# 3   -0.213078  0.027713  0.020821
# 4   -0.153957  0.024695  0.020995
# ..        ...       ...       ...
# 521 -0.192605  0.046943  0.032675
# 522 -0.185800  0.027574  0.021461
# 523 -0.294423  0.041799  0.029483
# 524 -0.440499  0.048627  0.033630
# 525 -0.349876  0.068786  0.041728
#
# [526 rows x 14 columns]

# %%
df.sort_values(['Sharpe Ratio', 'Annual Volatility'], ascending=[False, True], inplace=True)
