# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_nse = pd.read_excel('NSE.xlsx')
data_nifty50 = pd.read_excel('NIFTY_50.xlsx')
data_bnifty = pd.read_excel('NIFTY_BANK.xlsx')

# %%
df = pd.concat([data_nse, data_nifty50, data_bnifty], axis=0)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.drop_duplicates(subset=['TIC'])
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                TIC  Latest Price  Score  PE Ratio  Dividend        SMA_20  \
# 0        KERNEX.NS    371.750000    100       NaN      1.00    356.914996
# 1          NDTV.NS    357.850006    100     25.25      0.80    332.205000
# 2        ROHLTD.NS    267.600006     99       NaN      2.00    273.532503
# 3      ADANIENT.NS   4008.850098     98    587.89      1.00   3501.565002
# 4    OILCOUNTUB.NS     22.950001     99      1.01      2.00     20.902500
# ..             ...           ...    ...       ...       ...           ...
# 515   COALINDIA.NS    253.250000     93      5.97      3.00    243.805000
# 516   NESTLEIND.NS  20322.500000     86     90.50    120.00  19993.376563
# 517    HDFCLIFE.NS    542.650024     10     74.95      1.70    534.902502
# 518  IDFCFIRSTB.NS     57.549999     58     21.97      0.75     56.547500
# 519  BANDHANBNK.NS    226.350006     17      9.28      1.00    251.122503
#
#            SMA_50  52_Week_Low  52_Week_High  Annual Volatility  Sharpe Ratio  \
# ...

# %%
df.sort_values(['Sharpe Ratio', 'Annual Volatility'], ascending=[False, True], inplace=True)

# %%
new_data = df[(df['Sharpe Ratio'] > 1.2) & (df['Annual Volatility'] < 0.52) & (df['MaxDD'] > -0.32) & (df['Latest Price'] <= 600)]

# %%
new_data.to_excel('Nov_Invest.xlsx', index=False)
